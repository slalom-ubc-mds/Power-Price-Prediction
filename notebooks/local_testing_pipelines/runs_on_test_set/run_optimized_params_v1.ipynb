# %%
import pandas as pd
import numpy as np
from sktime.forecasting.base import ForecastingHorizon
from sklearn.metrics import mean_squared_error
import plotly.express as px

import warnings

warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../utils/")

# %%
import pipeline_helpers as ph

# %% [markdown]
# ### Pipeline to evaluate the optimized hyperparameters on the test set
# - Update pool price one at a time.

# %%
X_train = pd.read_csv(
    "https://raw.githubusercontent.com/slalom-ubc-mds/Power-Price-Prediction/main/data/processed/train/X_train.csv",
    parse_dates=["date"],
    index_col="date",
)

y_train = pd.read_csv(
    "https://raw.githubusercontent.com/slalom-ubc-mds/Power-Price-Prediction/main/data/processed/train/y_train.csv",
    parse_dates=["date"],
    index_col="date",
)

X_train = X_train.sort_values(by="date")
X_train = X_train.asfreq("H")
y_train = y_train.sort_values(by="date")
y_train = y_train.asfreq("H")

# %%
X_test = pd.read_csv(
    "https://raw.githubusercontent.com/slalom-ubc-mds/Power-Price-Prediction/main/data/processed/test/X_test.csv",
    parse_dates=["date"],
    index_col="date",
)

y_test = pd.read_csv(
    "https://raw.githubusercontent.com/slalom-ubc-mds/Power-Price-Prediction/main/data/processed/test/y_test.csv",
    parse_dates=["date"],
    index_col="date",
)

X_test = X_test.sort_values(by="date")
X_test = X_test.asfreq("H")
y_test = y_test.sort_values(by="date")
y_test = y_test.asfreq("H")

# %%
y_hist = pd.read_csv(
    "https://raw.githubusercontent.com/slalom-ubc-mds/Power-Price-Prediction/main/data/processed/filtered_target_medium.csv",
    parse_dates=["date"],
    index_col="date",
)

y_hist = y_hist.sort_values(by="date")
y_hist = y_hist.asfreq("H")

# %%
X_test = X_test[:"2023-02-28"]
y_test = y_test[:"2023-02-28"]

# %%
lgbm_pipeline = ph.initialize_optimized_lgbm_forecaster()
fh = ForecastingHorizon(np.arange(1, 12 + 1))

# %%
forecast_len = 12
step_length = 1

# %%
lgbm_pipeline.fit(y=y_train, X=X_train, fh=fh)
# Out:
# ForecastingPipeline(steps=[('forecaster',
#                             TransformedTargetForecaster(steps=[('forecast',
#                                                                 DirectTabularRegressionForecaster(estimator=LGBMRegressor(boosting_type='dart', device='gpu', learning_rate=0.01,
#               max_depth=15, n_estimators=1000, num_leaves=70, reg_alpha=30,
#               reg_lambda=20),
#                                                                                                   window_length=24))]))])

# %%
rolling_prediction_df = ph.get_rolling_predictions(lgbm_pipeline, X_train, X_test, y_test, fh, 1, forecast_len, verbose=True)
# Out:
# Updating with actual values at 2023-02-01 00:00:00
# Cut off before update: DatetimeIndex(['2023-01-31 23:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 00:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 01:00:00
# Cut off before update: DatetimeIndex(['2023-02-01'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 01:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 02:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 01:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 02:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 01:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 02:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 04:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 02:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 03:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 02:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 03:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 06:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 03:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 04:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 03:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 04:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 08:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 04:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 05:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 04:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 05:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 10:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 05:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 06:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 05:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 06:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 12:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 06:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 07:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 06:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 07:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 14:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 07:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 08:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 07:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 08:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 16:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 08:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 09:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 08:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 09:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 18:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 09:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 10:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 09:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 10:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 20:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 10:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 11:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 10:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 11:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-01 22:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 11:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 12:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 11:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 12:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 12:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 13:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 12:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 13:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 02:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 13:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 14:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 13:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 14:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 04:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 14:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 15:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 14:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 15:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 06:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 15:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 16:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 15:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 16:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 08:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 16:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 17:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 16:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 17:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 10:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 17:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 18:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 17:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 18:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 12:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 18:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 19:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 18:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 19:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 14:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 19:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 20:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 19:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 20:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 16:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 20:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 21:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 20:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 21:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 18:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 21:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 22:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 21:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 22:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 20:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 22:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-01 23:00:00
# Cut off before update: DatetimeIndex(['2023-02-01 22:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-01 23:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-02-02 22:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-01 23:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-02
00:00
# Cut off before update: DatetimeIndex(['2023-02-27 04:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 05:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-25 10:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 05:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 06:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 05:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 06:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-25 12:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 06:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 07:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 06:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 07:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-25 14:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 07:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 08:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 07:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 08:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-25 16:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 08:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 09:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 08:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 09:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-25 18:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 09:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 10:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 09:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 10:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-25 20:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 10:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 11:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 10:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 11:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-25 22:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 11:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 12:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 11:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 12:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 12:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 13:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 12:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 13:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 02:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 13:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 14:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 13:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 14:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 04:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 14:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 15:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 14:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 15:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 06:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 15:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 16:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 15:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 16:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 08:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 16:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 17:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 16:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 17:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 10:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 17:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 18:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 17:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 18:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 12:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 18:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 19:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 18:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 19:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 14:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 19:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 20:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 19:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 20:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 16:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 20:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 21:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 20:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 21:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 18:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 21:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 22:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 21:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 22:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 20:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 22:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-27 23:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 22:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-27 23:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-26 22:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-27 23:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 00:00:00
# Cut off before update: DatetimeIndex(['2023-02-27 23:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 00:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 01:00:00
# Cut off before update: DatetimeIndex(['2023-02-28'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 01:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 02:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 01:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 02:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 01:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 02:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 04:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 02:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 03:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 02:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 03:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 06:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 03:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 04:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 03:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 04:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 08:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 04:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 05:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 04:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 05:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 10:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 05:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 06:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 05:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 06:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 12:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 06:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 07:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 06:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 07:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 14:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 07:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 08:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 07:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 08:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 16:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 08:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 09:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 08:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 09:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 18:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 09:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 10:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 09:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 10:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 20:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 10:00:00
# ----------------------------------------------------------------------------------
# Updating with actual values at 2023-02-28 11:00:00
# Cut off before update: DatetimeIndex(['2023-02-28 10:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Cut off after update: DatetimeIndex(['2023-02-28 11:00:00'], dtype='datetime64[ns]', name='date', freq='H')
# Predicting for DatetimeIndex(['2023-03-27 22:00:00'], dtype='datetime64[ns]', name='date', freq=None)
# Update and prediction done for 2023-02-28 11:00:00
# ----------------------------------------------------------------------------------

# %%
fold_actuals, fold_predictions_list, rmse_list = ph.get_fold_predictions(rolling_prediction_df, y_test)
# Out:
# Average RMSE for each fold: 110.13433075135933
# STD RMSE for each fold: 106.28125998616316

# %%
predictions = ph.generate_step_predictions(rolling_prediction_df, y_test, forecast_len)

# %%
actuals, rmses = ph.generate_step_errors(predictions, y_test, forecast_len)
# Out:
# 1 Step RMSE for model: 107.11046737284137
# 2 Step RMSE for model: 136.06268056051417
# 3 Step RMSE for model: 149.2198136866857
# 4 Step RMSE for model: 152.4145569377403
# 5 Step RMSE for model: 154.82622498156888
# 6 Step RMSE for model: 156.02809931498643
# 7 Step RMSE for model: 158.49895748463464
# 8 Step RMSE for model: 159.54432905756894
# 9 Step RMSE for model: 161.89549550029065
# 10 Step RMSE for model: 164.1164286975117
# 11 Step RMSE for model: 163.75973373221444
# 12 Step RMSE for model: 163.43778999050693

# %%
ph.get_aeso_predictions(y_test.index[0], y_test.index[-1])
# Out:
# One step prediction errors for AESO forecasts: 99.49 CAD/MWh.
# As these are one step predictions, the error should be lesser than ours since ours is 12 step prediction errors.
